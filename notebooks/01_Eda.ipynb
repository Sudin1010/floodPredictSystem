# %% [markdown]
# Step1 - Import libraries

# %%
# %pip install matplotlib seaborn
# Out:
# Requirement already satisfied: matplotlib in /Users/sudinranabhat/Desktop/ProjectWork/floodPredictSystem/.venv/lib/python3.12/site-packages (3.11.1)
# Requirement already satisfied: seaborn in /Users/sudinranabhat/Desktop/ProjectWork/floodPredictSystem/.venv/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/sudinranabhat/Desktop/ProjectWork/floodPredictSystem/.venv/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/sudinranabhat/Desktop/ProjectWork/floodPredictSystem/.venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in /Users/sudinranabhat/Desktop/ProjectWork/floodPredictSystem/.venv/lib/python3.12/site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/sudinranabhat/Desktop/ProjectWork/floodPredictSystem/.venv/lib/python3.12/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.25 in /Users/sudinranabhat/Desktop/ProjectWork/floodPredictSystem/.venv/lib/python3.12/site-packages (from matplotlib) (2.5.1)
# Requirement already satisfied: packaging>=20.0 in /Users/sudinranabhat/Desktop/ProjectWork/floodPredictSystem/.venv/lib/python3.12/site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=9 in /Users/sudinranabhat/Desktop/ProjectWork/floodPredictSystem/.venv/lib/python3.12/site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in /Users/sudinranabhat/Desktop/ProjectWork/floodPredictSystem/.venv/lib/python3.12/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/sudinranabhat/Desktop/ProjectWork/floodPredictSystem/.venv/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in /Users/sudinranabhat/Desktop/ProjectWork/floodPredictSystem/.venv/lib/python3.12/site-packages (from seaborn) (3.0.3)
# Requirement already satisfied: six>=1.5 in /Users/sudinranabhat/Desktop/ProjectWork/floodPredictSystem/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Step2- Load required rows only

# %%
df = pd.read_csv("../data/raw/train.csv", nrows=40000)
df.head()
# Out:
#    id  MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 0   0                 5                   8                5              8
# 1   1                 6                   7                4              4
# 2   2                 6                   5                6              7
# 3   3                 3                   4                6              5
# 4   4                 5                   3                2              6
#
#    Urbanization  ClimateChange  DamsQuality  Siltation  AgriculturalPractices  \
# 0             6              4            4          3                      3
# 1             8              8            3          5                      4
# 2             3              7            1          5                      4
# 3             4              8            4          7                      6
# 4             4              4            3          3                      3
#
#    ...  DrainageSystems  CoastalVulnerability  Landslides  Watersheds  \
# 0  ...                5                     3           3           5
# 1  ...                7                     2           0           3
# 2  ...                7                     3           7           5
# 3  ...                2                     4           7           4
# 4  ...                2                     2           6           6
#
#    DeterioratingInfrastructure  PopulationScore  WetlandLoss  \
# 0                            4                7            5
# 1                            5                3            3
# 2                            6                8            2
# 3                            4                6            5
# 4                            4                1            2
#
#    InadequatePlanning  PoliticalFactors  FloodProbability
# 0                   7                 3             0.445
# 1                   4                 3             0.450
# 2                   3                 3             0.530
# 3                   7                 5             0.535
# 4                   3                 5             0.415
#
# [5 rows x 22 columns]

# %% [markdown]
#  Check dataset shape

# %%
df.shape
# Out:
# (40000, 22)

# %% [markdown]
# Check columns

# %%
df.columns
# Out:
# Index(['id', 'MonsoonIntensity', 'TopographyDrainage', 'RiverManagement',
#        'Deforestation', 'Urbanization', 'ClimateChange', 'DamsQuality',
#        'Siltation', 'AgriculturalPractices', 'Encroachments',
#        'IneffectiveDisasterPreparedness', 'DrainageSystems',
#        'CoastalVulnerability', 'Landslides', 'Watersheds',
#        'DeterioratingInfrastructure', 'PopulationScore', 'WetlandLoss',
#        'InadequatePlanning', 'PoliticalFactors', 'FloodProbability'],
#       dtype='str')

# %% [markdown]
# Step 6: Basic information

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   id                               40000 non-null  int64
#  1   MonsoonIntensity                 40000 non-null  int64
#  2   TopographyDrainage               40000 non-null  int64
#  3   RiverManagement                  40000 non-null  int64
#  4   Deforestation                    40000 non-null  int64
#  5   Urbanization                     40000 non-null  int64
#  6   ClimateChange                    40000 non-null  int64
#  7   DamsQuality                      40000 non-null  int64
#  8   Siltation                        40000 non-null  int64
#  9   AgriculturalPractices            40000 non-null  int64
#  10  Encroachments                    40000 non-null  int64
#  11  IneffectiveDisasterPreparedness  40000 non-null  int64
#  12  DrainageSystems                  40000 non-null  int64
#  13  CoastalVulnerability             40000 non-null  int64
#  14  Landslides                       40000 non-null  int64
#  15  Watersheds                       40000 non-null  int64
#  16  DeterioratingInfrastructure      40000 non-null  int64
#  17  PopulationScore                  40000 non-null  int64
#  18  WetlandLoss                      40000 non-null  int64
#  19  InadequatePlanning               40000 non-null  int64
#  20  PoliticalFactors                 40000 non-null  int64
#  21  FloodProbability                 40000 non-null  float64
# dtypes: float64(1), int64(21)
# memory usage: 6.7 MB

# %% [markdown]
# Step 7: Check missing values

# %%
df.isnull().sum()
# Out:
# id                                 0
# MonsoonIntensity                   0
# TopographyDrainage                 0
# RiverManagement                    0
# Deforestation                      0
# Urbanization                       0
# ClimateChange                      0
# DamsQuality                        0
# Siltation                          0
# AgriculturalPractices              0
# Encroachments                      0
# IneffectiveDisasterPreparedness    0
# DrainageSystems                    0
# CoastalVulnerability               0
# Landslides                         0
# Watersheds                         0
# DeterioratingInfrastructure        0
# PopulationScore                    0
# WetlandLoss                        0
# InadequatePlanning                 0
# PoliticalFactors                   0
# FloodProbability                   0
# dtype: int64

# %% [markdown]
# Step 8: Check duplicate values

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Step 9: Statistical summary

# %%
df.describe()
# Out:
#                 id  MonsoonIntensity  TopographyDrainage  RiverManagement  \
# count  40000.00000      40000.000000        40000.000000     40000.000000
# mean   19999.50000          4.917950            4.921225         4.965425
# std    11547.14972          2.053296            2.100733         2.075461
# min        0.00000          0.000000            0.000000         0.000000
# 25%     9999.75000          3.000000            3.000000         4.000000
# 50%    19999.50000          5.000000            5.000000         5.000000
# 75%    29999.25000          6.000000            6.000000         6.000000
# max    39999.00000         16.000000           17.000000        16.000000
#
#        Deforestation  Urbanization  ClimateChange   DamsQuality     Siltation  \
# count   40000.000000  40000.000000   40000.000000  40000.000000  40000.000000
# mean        4.937025      4.943650       4.920125      4.941550      4.935325
# std         2.042159      2.080777       2.053826      2.084812      2.072233
# min         0.000000      0.000000       0.000000      0.000000      0.000000
# 25%         4.000000      3.000000       3.000000      3.000000      3.000000
# 50%         5.000000      5.000000       5.000000      5.000000      5.000000
# 75%         6.000000      6.000000       6.000000      6.000000      6.000000
# max        15.000000     16.000000      16.000000     15.000000     16.000000
#
#        AgriculturalPractices  ...  DrainageSystems  CoastalVulnerability  \
# count           40000.000000  ...     40000.000000          40000.000000
# mean                4.954975  ...         4.953100              4.957975
# std                 2.068503  ...         2.072331              2.078585
# min                 0.000000  ...         0.000000              0.000000
# 25%                 4.000000  ...         4.000000              3.000000
# 50%                 5.000000  ...         5.000000              5.000000
# 75%                 6.000000  ...         6.000000              6.000000
# max                16.000000  ...        17.000000             16.000000
#
#          Landslides    Watersheds  DeterioratingInfrastructure  \
# count  40000.000000  40000.000000                 40000.000000
# mean       4.927375      4.910175                     4.918700
# std        2.070207      2.088759                     2.065659
# min        0.000000      0.000000                     0.000000
# 25%        3.000000      3.000000                     3.000000
# 50%        5.000000      5.000000                     5.000000
# 75%        6.000000      6.000000                     6.000000
# max       16.000000     16.000000                    16.000000
#
#        PopulationScore  WetlandLoss  InadequatePlanning  PoliticalFactors  \
# count     40000.000000  40000.00000        40000.000000      40000.000000
# mean          4.925775      4.96560            4.958875          4.946800
# std           2.081580      2.07991            2.082569          2.085217
# min           0.000000      0.00000            0.000000          0.000000
# 25%           3.000000      4.00000            3.000000          3.000000
# 50%           5.000000      5.00000            5.000000          5.000000
# 75%           6.000000      6.00000            6.000000          6.000000
# max          17.000000     16.00000           16.000000         16.000000
#
#        FloodProbability
# count      40000.000000
# mean           0.504572
# std            0.050844
# min            0.320000
# 25%            0.470000
# 50%            0.505000
# 75%            0.540000
# max            0.715000
#
# [8 rows x 22 columns]

# %% [markdown]
# Step 10: Remove ID column for EDA

# %%
df = df.drop("id", axis=1)
df.head()
# Out:
#    MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 0                 5                   8                5              8
# 1                 6                   7                4              4
# 2                 6                   5                6              7
# 3                 3                   4                6              5
# 4                 5                   3                2              6
#
#    Urbanization  ClimateChange  DamsQuality  Siltation  AgriculturalPractices  \
# 0             6              4            4          3                      3
# 1             8              8            3          5                      4
# 2             3              7            1          5                      4
# 3             4              8            4          7                      6
# 4             4              4            3          3                      3
#
#    Encroachments  ...  DrainageSystems  CoastalVulnerability  Landslides  \
# 0              4  ...                5                     3           3
# 1              6  ...                7                     2           0
# 2              5  ...                7                     3           7
# 3              8  ...                2                     4           7
# 4              3  ...                2                     2           6
#
#    Watersheds  DeterioratingInfrastructure  PopulationScore  WetlandLoss  \
# 0           5                            4                7            5
# 1           3                            5                3            3
# 2           5                            6                8            2
# 3           4                            4                6            5
# 4           6                            4                1            2
#
#    InadequatePlanning  PoliticalFactors  FloodProbability
# 0                   7                 3             0.445
# 1                   4                 3             0.450
# 2                   3                 3             0.530
# 3                   7                 5             0.535
# 4                   3                 5             0.415
#
# [5 rows x 21 columns]

# %% [markdown]
# Step 11: Target variable distribution

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["FloodProbability"], kde=True)
plt.title("Distribution of Flood Probability")
plt.xlabel("Flood Probability")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# Step 12: Feature distribution

# %%
df.drop("FloodProbability", axis=1).hist(figsize=(18,14), bins=20)
plt.suptitle("Feature Distribution of Original Dataset")
plt.show()

# %% [markdown]
# Step 13: Correlation heatmap

# %%
plt.figure(figsize=(16,12))
corr = df.corr()

sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".3f")
plt.title("Correlation Heatmap of Original Dataset")
plt.show()

# %% [markdown]
# Step 14: Correlation with target

# %%
corr = df.corr()
target_corr = corr["FloodProbability"].sort_values(ascending=False)

plt.figure(figsize=(8,10))
target_corr.drop("FloodProbability").plot(kind="barh")
plt.title("Feature Correlation with Flood Probability")
plt.xlabel("Correlation Value")
plt.ylabel("Features")
plt.show()

# %% [markdown]
# Step 15: Save sampled dataset

# %%
df.to_csv("../data/sample/train_sample.csv", index=False)
